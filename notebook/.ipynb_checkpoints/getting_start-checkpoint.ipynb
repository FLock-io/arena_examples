# %%
import requests
import json
import os

import sys
# Add the parent directory to the Python path
# This allows importing modules from the parent directory
# In Jupyter notebooks, __file__ is not defined, so we need to use a different approach

# sys.path.append('..')
# Print the current working directory
import os



notebook_dir = os.path.dirname(os.path.abspath('__file__'))
parent_dir = os.path.dirname(notebook_dir)
print(f"Parent folder path: {parent_dir}")
# Out:
# Parent folder path: /home/yifan

# %%
pwd
# Out:
# '/home/yifan/playground'

# %%
# This cell fetches task information from the Flock API
# It retrieves details about a specific task using its ID
# The response includes title, description, data, and important dates

task_id="6"
location = f'https://fed-ledger-prod.flock.io/api/v1/tasks/get?task_id={task_id}'
response = requests.get(location)
res = json.loads(response.text)
data_url = res["data"]["training_set_url"]
print(res['title'])
print(res['description'])
print(res['data'])
print(res['submission_phase_ends_at'])
print(res['final_validation_ends_at'])
# Out:
# AI Producer: SEEK48
# ...

# %%
response = requests.get(data_url, stream=True)
filename = "../data/demo_data.jsonl"
os.makedirs(os.path.dirname(filename), exist_ok=True)
with open(filename, "wb") as f:
    for chunk in response.iter_content(chunk_size=8192):
        if chunk:  # filter out keep-alive new chunks
            f.write(chunk)
    f.flush()
    os.fsync(f.fileno())
print(f"Data saved successfully to {filename}")
# Out:
# Data saved successfully to ../data/demo_data.jsonl

# %%
print(chunk)
# Out:
# b'"}, {"role": "user", "content": "\xe5\x80\x8b\xe4\xba\xba\xe3\x81\xae\xe7\x89\xb9\xe6\x80\xa7\xe3\x80\x81\xe3\x81\xa4\xe3\x81\xbe\xe3\x82\x8
# ...
